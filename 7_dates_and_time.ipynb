# %%
import pandas as pd

# %%
pd.to_datetime("25 December 1970")
# Out:
# Timestamp('1970-12-25 00:00:00')

# %%
pd.to_datetime(" Dec. 25 1970, 5pm")
# Out:
# Timestamp('1970-12-25 17:00:00')

# %%
dates=['21 April 2010 5pm','2 Dec. 2001 8pm','12.13.2001']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2010-04-21 17:00:00', '2001-12-02 20:00:00',
#                '2001-12-13 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('12/07/2010 23:00:9')
# Out:
# Timestamp('2010-12-07 23:00:09')

# %%
pd.to_datetime("12 April 2020")
# Out:
# Timestamp('2020-04-12 00:00:00')

# %%
pd.to_datetime('10/11/12',dayfirst=True)
# Out:
# Timestamp('2012-11-10 00:00:00')

# %%
pd.to_datetime('10/11/12',yearfirst=True)
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
pd.to_datetime('10/11/12',yearfirst=True,dayfirst=True)
# Out:
# Timestamp('2010-12-11 00:00:00')

# %%
pd.to_datetime('10/11/12',format="%d/%m/%y")
# Out:
# Timestamp('2012-11-10 00:00:00')

# %%
meetings=['Dec 12 2010 Meeting','Dec 15 2010 Meeting']
pd.to_datetime(meetings,format="%b %d %Y Meeting")
# Out:
# DatetimeIndex(['2010-12-12', '2010-12-15'], dtype='datetime64[ns]', freq=None)

# %%
ufo=pd.read_csv('data/nuforc_reports.csv')

# %%
ufo['date']=pd.to_datetime(ufo['date_time'])

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 8.7+ MB

# %%
ufo['date_time']=pd.to_datetime(ufo['date_time'])

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 8.7+ MB

# %%
nufo=pd.read_csv('data/nuforc_reports.csv', parse_dates=['date_time'])

# %%
nufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufo['date_time'].dt

# %%
ufo['date_time'].dt.year.value_counts()
# Out:
# 2014.0    8704
# 2012.0    8124
# 2013.0    7823
# 2015.0    6915
# 2019.0    5767
# 2016.0    5664
# 2011.0    5630
# 2008.0    5307
# 2017.0    5057
# 2009.0    4996
# 2010.0    4786
# 2007.0    4736
# 2006.0    3720
# 2018.0    3273
# 2005.0     566
# 2004.0     340
# 1997.0     300
# 2001.0     263
# 2000.0     243
# 2003.0     238
# 1998.0     229
# 2002.0     220
# 1999.0     220
# 1995.0     219
# 1996.0     200
# 1994.0     197
# 1978.0     195
# 1975.0     180
# 1977.0     169
# 1976.0     164
# 1974.0     148
# 1979.0     148
# 1993.0     148
# 1988.0     147
# 1973.0     138
# 1985.0     133
# 1990.0     132
# 1989.0     131
# 1980.0     131
# 1992.0     130
# 1987.0     124
# 1991.0     119
# 1986.0     111
# 1983.0     109
# 1981.0     106
# 1970.0     100
# 1982.0      97
# 1969.0      97
# 1972.0      92
# 1984.0      84
# 1971.0      68
# Name: date_time, dtype: int64

# %%
ufo['date_time'].dt.year.value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
ufo['date_time'].dt.hour.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ufo['date_time'].dt.dayofweek.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
(ufo['date_time']<"1980").value_counts()
# Out:
# False    86626
# True      1499
# Name: date_time, dtype: int64

# %%
ufo[ufo['date_time'].dt.hour==2.0]
# Out:
#                                                  summary               city  \
# 3      I was driving towards the intersection of fall...             Ottawa
# 14     Bright Circle of Light followed me from Oskalo...        Centerville
# 148                                Strange Vibrations...          Indianola
# 153    red ball ufo following small plane in tracy, c...              Tracy
# 181    Silver disk flies through sky making zigzaggin...          Beaverton
# ...                                                  ...                ...
# 87975  Massive triangle at very low altitude and low ...       Hawkinsville
# 88026  Triangle on fire traveling through the night s...  Panama City Beach
# 88027  At first It looked like a drone but it was mov...        Panama City
# 88056                                     MADAR Node 157          Pensacola
# 88097                             Hovering band of light           Columbia
#
# ...

# %%
ufo[ufo.date_time.between("1980","1981")].sort_values("date_time")
# Out:
#                                                  summary  \
# 7996   Very bright green light without sound moved ov...
# 69297  UFO flew in a zig-zag motion from north to sou...
# 4805   Super-colossal circle of rotating lights perpe...
# 26562  Two glowing disks seen over an Interstate high...
# 31449                                   Tracked by a UFO
# ...                                                  ...
# 79435  Winter...December....noticed a satellite trave...
# 4324   clearly a flying suacer, solid, bright, silent...
# 33117  Believe this to be linked to u.s airbase bentw...
# 16420                                     frozen in time
# 62160  Daughter spotted "plane on fire."  We watched ...
#
#                        city state           date_time     shape  \
# 7996           Indianapolis    IN 1980-01-01 01:00:00     light
# 69297               Laramie    WY 1980-01-01 20:00:00   unknown
# 4805                Toronto    ON 1980-01-15 21:45:00      disk
# ...

# %%
ufo[ufo['date_time']>"2019-12-22"]
# Out:
#                                                  summary  \
# 3892   Lights in a row.  ((NUFORC Note:  Starlink sat...
# 3893   I saw a very big circle like thing in the sky ...
# 3894   I saw and photographed an object hovering abou...
# 3895   I stepped out back and saw a straight line pro...
# 3896   string of lights evenly spaced moving across s...
# 3897   satellite like looking objects single file lin...
# 3898   OBJECTS APPEAR AS SATELLITES IN FORMATION.  ((...
# 3899   31 UFOs seen traveling SW to NE in a mostly ev...
# 3900   Lights in sky in straight line at satellite he...
# 3901   The objects looked very high altitude.  ((Star...
# 3902   There was a line of very noticeable lights  tr...
# 3903   8 lights flying S to  equal distance from each...
# 3904   The event was already occurring when I became ...
# 3905   As I stood on my balcony, I saw approximately ...
# 3906   String of white lights that disappeared into a...
# ...

# %%
ufo['date_time'].dt.year.value_counts().head(10)
# Out:
# 2014.0    8704
# 2012.0    8124
# 2013.0    7823
# 2015.0    6915
# 2019.0    5767
# 2016.0    5664
# 2011.0    5630
# 2008.0    5307
# 2017.0    5057
# 2009.0    4996
# Name: date_time, dtype: int64

# %%
ufo['date_time'].dt.date.value_counts().head(10)
# Out:
# 2015-11-07    290
# 2014-07-04    270
# 2010-07-04    210
# 2012-07-04    200
# 2013-07-04    185
# 2015-07-04    178
# 2011-07-04    163
# 2009-09-19    129
# 2016-07-27    104
# 2014-01-01    103
# Name: date_time, dtype: int64

# %%
recent_cases = ufo[ufo['date_time'].dt.year>=2018]
recent_cases["date_time"].dt.date.value_counts().head(10)
# Out:
# 2019-11-11    77
# 2019-05-25    69
# 2019-05-26    67
# 2019-05-24    60
# 2019-07-04    57
# 2019-11-24    50
# 2019-12-22    50
# 2019-10-05    49
# 2018-07-04    40
# 2019-09-21    40
# Name: date_time, dtype: int64

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 8.7+ MB

# %%
ufo
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufo["posted"]=pd.to_datetime(ufo["posted"])

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(2), object(8)
# memory usage: 8.7+ MB

# %%
ufo['difference']=ufo['posted']-ufo['date_time']

# %%
ufo
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufo.difference.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 88125 entries, 0 to 88124
# Series name: difference
# Non-Null Count  Dtype
# --------------  -----
# 86938 non-null  timedelta64[ns]
# dtypes: timedelta64[ns](1)
# memory usage: 688.6 KB

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
#  13  difference      86938 non-null  timedelta64[ns]
# dtypes: datetime64[ns](3), float64(2), object(8), timedelta64[ns](1)
# memory usage: 9.4+ MB

# %%
longest_wait=ufo.difference.sort_values(ascending=False).head(10)

# %%
longest_wait.dt.days/365
# Out:
# 86762    50.583562
# 87145    50.282192
# 721      50.175342
# 1576     50.101370
# 1580     49.972603
# 84984    49.586301
# 83965    49.213699
# 722      49.180822
# 723      49.052055
# 1301     48.967123
# Name: difference, dtype: float64

# %%
longest_wait.dt.seconds
# Out:
# 86762        0
# 87145    81000
# 721      10800
# 1576         0
# 1580     28800
# 84984    82800
# 83965        0
# 722          0
# 723      79200
# 1301     21600
# Name: difference, dtype: int64

# %%
ufo['wait_days']=ufo['difference'].dt.days

# %%
ufo.sort_values('wait_days').head(10)
# Out:
#                                                  summary  \
# 4965   Night flying "airplane" with search lights obs...
# 28293  Miracle of the SunFrom Wikipedia, the free enc...
# 85714  7-8 elongated objects flying in straight line ...
# 25030  two star light objects moving very fast, in ab...
# 31261  Clump of small disc shaped cloud with light gr...
# 52932  03/19/2014 sighting:  Flash of light, luminati...
# 35377  Star like object, changed dir. randomly and di...
# 26084            3 Lights Flashing in Auburn, Washington
# 35745  Fireball type UFO changed direction; stayed st...
# 26085                       Fast moving lights in trees.
#
#                                   city state           date_time      shape  \
# 4965                      Meeting Lake    SK 2014-09-15 21:30:00    unknown
# 28293                Fatima (Portugal)   NaN 2017-10-13 00:00:00       disk
# 85714                       Wilmington    NC 2019-12-29 20:40:00      cigar
# ...

# %%
# bill=pd.read_csv('data/billboard_charts.csv',parse_dates=["date"])
bill=pd.read_csv('data/billboard_charts.csv')

# %%
bill
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# ...

# %%
bill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  object
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 17.6+ MB

# %%
bill['date']=pd.to_datetime(bill['date'])

# %%
bill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
bill.count()
# Out:
# date              330087
# rank              330087
# song              330087
# artist            330087
# last-week         297775
# peak-rank         330087
# weeks-on-board    330087
# dtype: int64

# %%
bill.artist.value_counts().head(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
bill
# Out:
#              date  rank                                 song  \
# 0      2021-11-06     1                           Easy On Me
# 1      2021-11-06     2                                 Stay
# 2      2021-11-06     3                        Industry Baby
# 3      2021-11-06     4                           Fancy Like
# 4      2021-11-06     5                           Bad Habits
# ...           ...   ...                                  ...
# 330082 1958-08-04    96                        Over And Over
# 330083 1958-08-04    97                     I Believe In You
# 330084 1958-08-04    98                      Little Serenade
# 330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086 1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
top_1=bill['rank']==1

# %%
bill[top_1].artist.value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
bill[top_1].song.value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
otr=bill['song']=="Old Town Road"
p=bill[otr].set_index("date")['rank'].plot()
p.invert_yaxis()
