# %%
import pandas as pd
titanic=pd.read_csv('titanic.csv')
houses=pd.read_csv('kc_house_data.csv')
netflix=pd.read_csv('netflix_titles.csv')
btc=pd.read_csv('BTC-USD.csv')
whr=pd.read_csv('world-happiness-report-2021.csv')

# %%
# btc.drop(labels=["Volume", "Adj Close"],inplace=True)
# btc.drop(columns=["Volume","Adj Close"])
btc
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2742  2022-03-21  41246.132813  41454.410156  40668.042969  41077.996094
# 2743  2022-03-22  41074.105469  43124.707031  40948.281250  42358.808594
# 2744  2022-03-23  42364.378906  42893.507813  41877.507813  42892.957031
# 2745  2022-03-24  42886.652344  44131.855469  42726.164063  43960.933594
# 2746  2022-03-25  43958.675781  44982.519531  43711.871094  44395.964844
#
#          Adj Close       Volume
# 0       457.334015     21056800
# ...

# %%
btc[["Open","Close","Low","High"]]
# Out:
#               Open         Close           Low          High
# 0       465.864014    457.334015    452.421997    468.174011
# 1       456.859985    424.440002    413.104004    456.859985
# 2       424.102997    394.795990    384.532013    427.834991
# 3       394.673004    408.903992    389.882996    423.295990
# 4       408.084991    398.821014    393.181000    412.425995
# ...            ...           ...           ...           ...
# 2742  41246.132813  41077.996094  40668.042969  41454.410156
# 2743  41074.105469  42358.808594  40948.281250  43124.707031
# 2744  42364.378906  42892.957031  41877.507813  42893.507813
# 2745  42886.652344  43960.933594  42726.164063  44131.855469
# 2746  43958.675781  44395.964844  43711.871094  44982.519531
#
# [2747 rows x 4 columns]

# %%
whr.set_index("Country name",inplace=True)

# %%
whr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
whr.drop(labels="Denmark",axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries=["Denmark","United States", "Finland"]
whr.drop(countries)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# ...

# %%
btc.sort_index(ascending=False,inplace=True)
btc
# Out:
#             Date          Open          High           Low         Close  \
# 2746  2022-03-25  43958.675781  44982.519531  43711.871094  44395.964844
# 2745  2022-03-24  42886.652344  44131.855469  42726.164063  43960.933594
# 2744  2022-03-23  42364.378906  42893.507813  41877.507813  42892.957031
# 2743  2022-03-22  41074.105469  43124.707031  40948.281250  42358.808594
# 2742  2022-03-21  41246.132813  41454.410156  40668.042969  41077.996094
# ...          ...           ...           ...           ...           ...
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
#
#          Adj Close       Volume
# 2746  44395.964844  30379415552
# ...

# %%
btc.drop(btc.index[0:3])
# Out:
#             Date          Open          High           Low         Close  \
# 2743  2022-03-22  41074.105469  43124.707031  40948.281250  42358.808594
# 2742  2022-03-21  41246.132813  41454.410156  40668.042969  41077.996094
# 2741  2022-03-20  42191.406250  42241.164063  41004.757813  41247.824219
# 2740  2022-03-19  41794.648438  42316.554688  41602.667969  42190.652344
# 2739  2022-03-18  40944.839844  42195.746094  40302.398438  41801.156250
# ...          ...           ...           ...           ...           ...
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
#
#          Adj Close       Volume
# 2743  42358.808594  32004652376
# ...

# %%
btc.drop(0)
# Out:
#             Date          Open          High           Low         Close  \
# 2746  2022-03-25  43958.675781  44982.519531  43711.871094  44395.964844
# 2745  2022-03-24  42886.652344  44131.855469  42726.164063  43960.933594
# 2744  2022-03-23  42364.378906  42893.507813  41877.507813  42892.957031
# 2743  2022-03-22  41074.105469  43124.707031  40948.281250  42358.808594
# 2742  2022-03-21  41246.132813  41454.410156  40668.042969  41077.996094
# ...          ...           ...           ...           ...           ...
# 5     2014-09-22    399.100006    406.915985    397.130005    402.152008
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
#
#          Adj Close       Volume
# 2746  44395.964844  30379415552
# ...

# %%
titanic["Species"]="Human"

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
houses.insert(0,"county", "King County")

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
houses["num_Bedrooms"]=houses['bedrooms']

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
houses.insert(3, "Actual_price", houses['price'])

# %%
houses
# Out:
#             county          id             date  Actual_price     price  \
# 0      King County  7129300520  20141013T000000      221900.0  221900.0
# 1      King County  6414100192  20141209T000000      538000.0  538000.0
# 2      King County  5631500400  20150225T000000      180000.0  180000.0
# 3      King County  2487200875  20141209T000000      604000.0  604000.0
# 4      King County  1954400510  20150218T000000      510000.0  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000      360000.0  360000.0
# 21609  King County  6600060120  20150223T000000      400000.0  400000.0
# 21610  King County  1523300141  20140623T000000      402101.0  402101.0
# 21611  King County   291310100  20150116T000000      400000.0  400000.0
# 21612  King County  1523300157  20141015T000000      325000.0  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# ...

# %%
# titanic.insert(8, "Num_relatives", titanic["SibSp"]+titanic["Parch"])
# titanic
titanic.drop(labels=["Species"], axis=1,inplace=True)

# %%
# titanic[titanic["Survived"]==1].sort_values('Num_relatives', ascending=False)

# %%
# titanic[titanic["Num_relatives"]==0].Sex.value_counts().plot(kind="pie")

# %%
# titanic[titanic["Num_relatives"]==0].Pclass.value_counts().plot(kind="pie")

# %%
houses["price_sqft"]=houses['price']/houses['sqft_living']
houses.sort_values("price_sqft",ascending=False).head(50)['zipcode'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# btc.set_index("Date",inplace=True)
btc["Difference"]=btc["High"]-btc["Low"]

# %%
btc.Difference.sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# whr=pd.read_csv('world-happiness-report-2021.csv')
whr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper={"Regional indicator":"regional_indicator", "Ladder score":"ladder_score"}
whr.rename(columns=mapper)
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
# mapper={"Finland":"finland","Denmark":"denmark"}
# whr.rename(index=mapper,inplace=True)

# %%
# whr.set_index("Country name",inplace=True)

# %%
mapper={"Finland":"finland","Denmark":"denmark"}
whr.rename(index=mapper,inplace=True)

# %%
whr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
titanic["Sex"].replace(["M","F"],["F","M"],inplace=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic['Age'].replace([27],[None],inplace=True)   # Jab kisi ko none se replace krna hota hai to hamesha list use krte hain

# %%
titanic.Age.value_counts(dropna=False)
# Out:
# NaN     86
# 24.0    17
# 21.0    17
# 22.0    16
# 30.0    15
#         ..
# 76.0     1
# 28.5     1
# 22.5     1
# 62.0     1
# 38.5     1
# Name: Age, Length: 80, dtype: int64

# %%
titanic.loc[1:100]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 96           988         1       1
# 97           989         0       3
# 98           990         1       3
# 99           991         0       3
# 100          992         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 3                                     Wirz, Mr. Albert    male  None      0
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                           Svensson, Mr. Johan Cervin    male  14.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
whr.loc["Brazil":"India"]
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Brazil        Latin America and Caribbean         6.330
# Mexico        Latin America and Caribbean         6.317
# Jamaica       Latin America and Caribbean         6.309
# Lithuania      Central and Eastern Europe         6.255
# Cyprus                     Western Europe         6.223
# ...                                   ...           ...
# Madagascar             Sub-Saharan Africa         4.208
# Togo                   Sub-Saharan Africa         4.107
# Zambia                 Sub-Saharan Africa         4.073
# Sierra Leone           Sub-Saharan Africa         3.849
# India                          South Asia         3.819
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
# Mexico                                 0.053         6.420         6.213
# ...

# %%
# whr.rename(columns={"Ladder Score": "ladder_score"},inplace=True)
# mapper={"Regional indicator":"regional_indicator","Country name":"country"}
# whr.rename(columns={"Country name":"country"}

# %%
 whr.rename(columns={ "Regional indicator":"country_anme", "Ladder score":"ladder_score"})
# Out:
#                     country_anme  ladder_score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
whr.loc[["Denmark","Finland"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22844\488168891.py in <module>
# ----> 1 whr.loc[["Denmark","Finland"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1192                     raise ValueError("Cannot index with multidimensional key")
#    1193
# -> 1194                 return self._getitem_iterable(key, axis=axis)
#    1195
#    1196             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1130
# ...

# %%
whr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
# whr.loc["Finland":"India",["Ladder score"]].sort_values("Ladder score", ascending=False).head(20).plot(kind='bar')

# %%
# whr.loc[["Finland","India","United States"],["Ladder score"]].sort_values("Ladder score", ascending=False).head(20).plot(kind='bar')

# %%
# whr.loc[["Denmark","Sweden","Norway"],["Regional indicator"]]="Tall people country"

# %%
whr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
# whr.loc[["Denmark","Sweden","Norway"],["Regional indicator"]]

# %%
whr.loc["Finland"]="LOL"

# %%
whr
# Out:
#               Regional indicator Ladder score Standard error of ladder score  \
# Country name
# finland           Western Europe        7.842                          0.032
# denmark           Western Europe         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
# Finland                      LOL          LOL                            LOL
#
# ...

# %%
whr.loc["Finland",["upperwhisker","lowerwhisker"]]="Meow"

# %%
whr
# Out:
#               Regional indicator Ladder score Standard error of ladder score  \
# Country name
# finland           Western Europe        7.842                          0.032
# denmark           Western Europe         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
# Finland                      LOL          LOL                            LOL
#
# ...

# %%
# whr.loc[["Finland","Norway","Denmark","Switzerland"],['Regional indicator']]

# %%
# whr.loc[["Finland","Norway","Denmark","Switzerland"],['Regional indicator','isCold?']]=["Nordiac Countries","Yes"]

# %%
# whr.loc[["Finland","Norway","Denmark","Switzerland"],['Regional indicator','isCold?']]/

# %%
whr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, finland to Finland
# Data columns (total 19 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Regional indicator                          150 non-null    object
#  1   Ladder score                                150 non-null    object
#  2   Standard error of ladder score              150 non-null    object
#  3   upperwhisker                                150 non-null    object
#  4   lowerwhisker                                150 non-null    object
#  5   Logged GDP per capita                       150 non-null    object
#  6   Social support                              150 non-null    object
#  7   Healthy life expectancy                     150 non-null    object
#  8   Freedom to make life choices                150 non-null    object
# ...

# %%
whr.describe()
# Out:
#         Regional indicator  Ladder score  Standard error of ladder score  \
# count                  150       150.000                         150.000
# unique                  11       148.000                          66.000
# top     Sub-Saharan Africa         5.477                           0.046
# freq                    36         2.000                           7.000
#
#         upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# count        150.000       150.000                150.000         150.000
# unique       147.000       144.000                149.000         120.000
# top            5.397         5.001                 10.576           0.954
# freq           2.000         2.000                  2.000           3.000
#
#         Healthy life expectancy  Freedom to make life choices  Generosity  \
# count                     150.0                       150.000     150.000
# unique                    136.0                       127.000     131.000
# ...

# %%
whr
# Out:
#               Regional indicator Ladder score Standard error of ladder score  \
# Country name
# finland           Western Europe        7.842                          0.032
# denmark           Western Europe         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
# Finland                      LOL          LOL                            LOL
#
# ...

# %%
houses
# Out:
#             county          id             date  Actual_price     price  \
# 0      King County  7129300520  20141013T000000      221900.0  221900.0
# 1      King County  6414100192  20141209T000000      538000.0  538000.0
# 2      King County  5631500400  20150225T000000      180000.0  180000.0
# 3      King County  2487200875  20141209T000000      604000.0  604000.0
# 4      King County  1954400510  20150218T000000      510000.0  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000      360000.0  360000.0
# 21609  King County  6600060120  20150223T000000      400000.0  400000.0
# 21610  King County  1523300141  20140623T000000      402101.0  402101.0
# 21611  King County   291310100  20150116T000000      400000.0  400000.0
# 21612  King County  1523300157  20141015T000000      325000.0  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
many_bedrooms=houses["bedrooms"]>=10   # Boolean mask
# many_bedrooms

# %%
houses.loc[many_bedrooms,["bedrooms"]]="TOO MANY"

# %%
houses.loc[many_bedrooms,["bedrooms"]]
# Out:
#        bedrooms
# 8757   TOO MANY
# 13314  TOO MANY
# 15161  TOO MANY
# 15870  TOO MANY
# 19254  TOO MANY

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   county         21613 non-null  object
#  1   id             21613 non-null  int64
#  2   date           21613 non-null  object
#  3   Actual_price   21613 non-null  float64
#  4   price          21613 non-null  float64
#  5   bedrooms       21613 non-null  object
#  6   bathrooms      21613 non-null  float64
#  7   sqft_living    21613 non-null  int64
#  8   sqft_lot       21613 non-null  int64
#  9   floors         21613 non-null  float64
#  10  waterfront     21613 non-null  int64
#  11  view           21613 non-null  int64
#  12  condition      21613 non-null  int64
#  13  grade          21613 non-null  int64
#  14  sqft_above     21613 non-null  int64
#  15  sqft_basement  21613 non-null  int64
#  16  yr_built       21613 non-null  int64
# ...

# %%
houses
# Out:
#             county          id             date  Actual_price     price  \
# 0      King County  7129300520  20141013T000000      221900.0  221900.0
# 1      King County  6414100192  20141209T000000      538000.0  538000.0
# 2      King County  5631500400  20150225T000000      180000.0  180000.0
# 3      King County  2487200875  20141209T000000      604000.0  604000.0
# 4      King County  1954400510  20150218T000000      510000.0  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000      360000.0  360000.0
# 21609  King County  6600060120  20150223T000000      400000.0  400000.0
# 21610  King County  1523300141  20140623T000000      402101.0  402101.0
# 21611  King County   291310100  20150116T000000      400000.0  400000.0
# 21612  King County  1523300157  20141015T000000      325000.0  325000.0
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
high_quality=houses.grade>11
good_view = houses.view==4
# good_view
houses['Standard']="Normal"
# houses.loc[high_quality & good_view, ['Standard']]="Ultra"

# %%
houses.loc[high_quality & good_view, ['Standard']]="Ultra"

# %%
houses.columns
# Out:
# Index(['county', 'id', 'date', 'Actual_price', 'price', 'bedrooms',
#        'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view',
#        'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15',
#        'num_Bedrooms', 'price_sqft', 'Standard'],
#       dtype='object')

# %%
pd.options.display.min_rows=10
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   county         21613 non-null  object
#  1   id             21613 non-null  int64
#  2   date           21613 non-null  object
#  3   Actual_price   21613 non-null  float64
#  4   price          21613 non-null  float64
#  5   bedrooms       21613 non-null  object
#  6   bathrooms      21613 non-null  float64
#  7   sqft_living    21613 non-null  int64
#  8   sqft_lot       21613 non-null  int64
#  9   floors         21613 non-null  float64
#  10  waterfront     21613 non-null  int64
#  11  view           21613 non-null  int64
#  12  condition      21613 non-null  int64
#  13  grade          21613 non-null  int64
#  14  sqft_above     21613 non-null  int64
#  15  sqft_basement  21613 non-null  int64
#  16  yr_built       21613 non-null  int64
# ...

# %%
houses.nlargest(10,['grade','view'])
# Out:
#             county          id             date  Actual_price      price  \
# 9254   King County  9208900037  20140919T000000     6885000.0  6885000.0
# 14556  King County  2303900035  20140611T000000     2888000.0  2888000.0
# 19017  King County  2303900100  20140911T000000     3800000.0  3800000.0
# 7252   King County  6762700020  20141013T000000     7700000.0  7700000.0
# 10373  King County  3303850390  20141212T000000     2983000.0  2983000.0
# 6041   King County  1725059316  20141120T000000     2385000.0  2385000.0
# 7035   King County   853200010  20140701T000000     3800000.0  3800000.0
# 13411  King County  2426039123  20150130T000000     2415000.0  2415000.0
# 4411   King County  2470100110  20140804T000000     5570000.0  5570000.0
# 4811   King County  9831200500  20150304T000000     2479000.0  2479000.0
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  yr_built  \
# 9254         6       7.75         9890     31374     2.0  ...      2001
# ...

# %%
# pd.options.display.min_columns=25

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   county         21613 non-null  object
#  1   id             21613 non-null  int64
#  2   date           21613 non-null  object
#  3   Actual_price   21613 non-null  float64
#  4   price          21613 non-null  float64
#  5   bedrooms       21613 non-null  object
#  6   bathrooms      21613 non-null  float64
#  7   sqft_living    21613 non-null  int64
#  8   sqft_lot       21613 non-null  int64
#  9   floors         21613 non-null  float64
#  10  waterfront     21613 non-null  int64
#  11  view           21613 non-null  int64
#  12  condition      21613 non-null  int64
#  13  grade          21613 non-null  int64
#  14  sqft_above     21613 non-null  int64
#  15  sqft_basement  21613 non-null  int64
#  16  yr_built       21613 non-null  int64
# ...

# %%
houses[houses['bathrooms'].between(5,7)].bathrooms.value_counts()
# Out:
# 5.00    21
# 5.25    13
# 5.50    10
# 6.00     6
# 5.75     4
# 6.75     2
# 6.25     2
# 6.50     2
# Name: bathrooms, dtype: int64

# %%
# houses.director.isna()
netflix.isna()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
netflix.notna()
# Out:
#       show_id  type  title  director   cast  country  date_added  \
# 0        True  True   True      True  False     True        True
# 1        True  True   True     False   True     True        True
# 2        True  True   True      True   True    False        True
# 3        True  True   True     False  False    False        True
# 4        True  True   True     False   True     True        True
# ...       ...   ...    ...       ...    ...      ...         ...
# 8802     True  True   True      True   True     True        True
# 8803     True  True   True     False  False    False        True
# 8804     True  True   True      True   True     True        True
# 8805     True  True   True      True   True     True        True
# 8806     True  True   True      True   True     True        True
#
#       release_year  rating  duration  listed_in  description
# 0             True    True      True       True         True
# 1             True    True      True       True         True
# ...

# %%
netflix.rename(columns={"release_year":"release_yr"})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.drop(labels={"type"}, axis=1)
# Out:
#      show_id                  title         director  \
# 0         s1   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2          Blood & Water              NaN
# 2         s3              Ganglands  Julien Leclercq
# 3         s4  Jailbirds New Orleans              NaN
# 4         s5           Kota Factory              NaN
# ...      ...                    ...              ...
# 8802   s8803                 Zodiac    David Fincher
# 8803   s8804            Zombie Dumb              NaN
# 8804   s8805             Zombieland  Ruben Fleischer
# 8805   s8806                   Zoom     Peter Hewitt
# 8806   s8807                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
netflix.drop(netflix.index[1:9])
# Out:
#      show_id     type                                title  \
# 0         s1    Movie                 Dick Johnson Is Dead
# 9        s10    Movie                         The Starling
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 11       s12  TV Show                     Bangkok Breaking
# 12       s13    Movie                         Je Suis Karl
# ...      ...      ...                                  ...
# 8802   s8803    Movie                               Zodiac
# 8803   s8804  TV Show                          Zombie Dumb
# 8804   s8805    Movie                           Zombieland
# 8805   s8806    Movie                                 Zoom
# 8806   s8807    Movie                               Zubaan
#
#                  director                                               cast  \
# 0         Kirsten Johnson                                                NaN
# 9          Theodore Melfi  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
btc.drop(labels=2745,axis=0)
# Out:
#             Date          Open          High           Low         Close  \
# 2746  2022-03-25  43958.675781  44982.519531  43711.871094  44395.964844
# 2744  2022-03-23  42364.378906  42893.507813  41877.507813  42892.957031
# 2743  2022-03-22  41074.105469  43124.707031  40948.281250  42358.808594
# 2742  2022-03-21  41246.132813  41454.410156  40668.042969  41077.996094
# 2741  2022-03-20  42191.406250  42241.164063  41004.757813  41247.824219
# ...          ...           ...           ...           ...           ...
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
#
#          Adj Close       Volume   Difference
# 2746  44395.964844  30379415552  1270.648437
# ...
