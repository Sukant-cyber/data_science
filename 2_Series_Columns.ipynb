# %%
import pandas as pd
houses=pd.read_csv('kc_house_data.csv')
titanic=pd.read_csv('titanic.csv')
df=pd.read_csv('pincode.csv')

# %%
df
# Out:
#          ZIP        LAT         LNG
# 0        601  18.180555  -66.749961
# 1        602  18.361945  -67.175597
# 2        603  18.455183  -67.119887
# 3        606  18.158345  -66.932911
# 4        610  18.295366  -67.125135
# ...      ...        ...         ...
# 33139  99923  56.002315 -130.041026
# 33140  99925  55.550204 -132.945933
# 33141  99926  55.138352 -131.470424
# 33142  99927  56.239062 -133.457924
# 33143  99929  56.370751 -131.693301
#
# [33144 rows x 3 columns]

# %%
# df['ZIP','LAT']                        # Error in the above code

# %%
type(houses.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.price.sum()
# Out:
# 11672925008.0

# %%
prices=houses.price
prices.min()
# Out:
# 75000.0

# %%
prices.shape
# Out:
# (21613,)

# %%
prices.size
# Out:
# 21613

# %%
prices.describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
minse=houses.min(numeric_only=True)

# %%
type(minse.index)
# Out:
# pandas.core.indexes.base.Index

# %%
houses["price"].head(15).median()
# Out:
# 400000.0

# %%
x=houses["price"].nunique(dropna=False)
x
# Out:
# 4028

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic["Age"].nunique()
# Out:
# 79

# %%
titanic["Age"].nunique(dropna=False)
# Out:
# 80

# %%
houses.price.nsmallest(5, keep='all')
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# Name: price, dtype: float64

# %%
titanic.Pclass.nlargest(keep='all')
# Out:
# 0      3
# 1      3
# 3      3
# 4      3
# 5      3
#       ..
# 412    3
# 413    3
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 218, dtype: int64

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.nlargest(10,["bedrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses.nlargest(10,["bedrooms","bathrooms","sqft_living"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses.nlargest(10,["bedrooms","bathrooms"])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
cols=["price","bathrooms","bedrooms"]
houses[cols]
# Out:
#           price  bathrooms  bedrooms
# 0      221900.0       1.00         3
# 1      538000.0       2.25         3
# 2      180000.0       1.00         2
# 3      604000.0       3.00         4
# 4      510000.0       2.00         3
# ...         ...        ...       ...
# 21608  360000.0       2.50         3
# 21609  400000.0       2.50         4
# 21610  402101.0       0.75         2
# 21611  400000.0       2.50         3
# 21612  325000.0       0.75         2
#
# [21613 rows x 3 columns]

# %%
houses["bedrooms"].value_counts(ascending=False).head(10)
# Out:
# 3    9824
# 4    6882
# 2    2760
# 5    1601
# 6     272
# 1     199
# 7      38
# 0      13
# 8      13
# 9       6
# Name: bedrooms, dtype: int64

# %%
houses[["bedrooms","bathrooms","price"]].value_counts()
# Out:
# bedrooms  bathrooms  price
# 3         1.00       350000.0    26
# 2         1.00       425000.0    25
# 3         1.00       225000.0    24
# 2         1.00       325000.0    23
# 3         1.00       230000.0    23
#                                  ..
#           2.50       272500.0     1
#                      273000.0     1
#                      273500.0     1
#                      274000.0     1
# 33        1.75       640000.0     1
# Length: 12473, dtype: int64

# %%
houses.bedrooms
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
houses.bedrooms.plot()
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='bedrooms'>

# %%
houses[["bedrooms","bathrooms"]].plot()
# Out:
# <AxesSubplot:>

# %%
# houses[["bedrooms","bathrooms"]].value_counts().plot(kind="kde")

# %%
df=houses[["bedrooms","bathrooms"]]
df.plot(kind="hist",x='bedrooms',y='bathrooms')
# Out:
# <AxesSubplot:ylabel='Frequency'>
