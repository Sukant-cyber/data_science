# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
car=pd.read_csv('data/car_stocks.csv')

# %%
car
# Out:
#    Symbol        Date        Open        High         Low       Close  \
# 0    RIVN  2021-11-10  106.750000  119.459999   95.199997  100.730003
# 1    RIVN  2021-11-11  114.625000  125.000000  108.010002  122.989998
# 2    RIVN  2021-11-12  128.645004  135.199997  125.250000  129.949997
# 3    RIVN  2021-11-15  130.800003  152.529999  127.510002  149.360001
# 4    RIVN  2021-11-16  163.800003  179.470001  153.779999  172.009995
# 5    RIVN  2021-11-17  160.880005  163.000000  140.350006  146.070007
# 6    RIVN  2021-11-18  136.809998  138.779999  120.150002  123.379997
# 7    RIVN  2021-11-19  129.979996  139.899994  125.599998  128.600006
# 8    RIVN  2021-11-22  123.879997  124.930000  106.910004  118.110001
# 9    RIVN  2021-11-23  117.830002  124.000000  113.000000  119.849998
# 10   RIVN  2021-11-24  119.379997  120.000000  113.449997  114.849998
# 11   RIVN  2021-11-26  111.000000  114.500000  106.139999  112.129997
# ...

# %%
car[car['Symbol']=="RIVN"]['Close'].mean()
# Out:
# 127.52307653846154

# %%
car[car['Symbol']=="GM"]['Close'].mean()
# Out:
# 62.16461546153845

# %%
car[car['Symbol']=="LCID"]['Close'].mean()
# Out:
# 49.82923061538462

# %%
car.groupby("Symbol")['Close'].mean()
# Out:
# Symbol
# GM       62.164615
# LCID     49.829231
# RIVN    127.523077
# Name: Close, dtype: float64

# %%
titanic=pd.read_csv('data/titanic.csv')
# titanic['age'].value_counts(dropna=False)
titanic['age'].replace(["?"],[None], inplace=True)
titanic['age']=pd.to_numeric(titanic['age'])

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
df=titanic[['pclass','survived','age','sex']]
# df
gbo=df.groupby('sex')

# %%
gbo.ngroups
# Out:
# 2

# %%
gbo.groups
# Out:
# {'female': [0, 2, 4, 6, 8, 11, 12, 13, 17, 18, 21, 23, 24, 27, 28, 32, 33, 35, 36, 41, 42, 43, 44, 48, 50, 55, 57, 59, 61, 63, 65, 66, 67, 69, 72, 73, 76, 78, 79, 82, 83, 85, 88, 90, 92, 95, 97, 98, 99, 102, 103, 104, 105, 107, 108, 111, 112, 113, 116, 117, 121, 122, 124, 127, 129, 130, 131, 134, 137, 139, 141, 144, 146, 149, 153, 155, 159, 160, 161, 163, 167, 168, 169, 176, 178, 180, 181, 182, 186, 187, 188, 190, 192, 193, 195, 198, 199, 204, 207, 208, ...], 'male': [1, 3, 5, 7, 9, 10, 14, 15, 16, 19, 20, 22, 25, 26, 29, 30, 31, 34, 37, 38, 39, 40, 45, 46, 47, 49, 51, 52, 53, 54, 56, 58, 60, 62, 64, 68, 70, 71, 74, 75, 77, 80, 81, 84, 86, 87, 89, 91, 93, 94, 96, 100, 101, 106, 109, 110, 114, 115, 118, 119, 120, 123, 125, 126, 128, 132, 133, 135, 136, 138, 140, 142, 143, 145, 147, 148, 150, 151, 152, 154, 156, 157, 158, 162, 164, 165, 166, 170, 171, 172, 173, 174, 175, 177, 179, 183, 184, 185, 189, 191, ...]}

# %%
gbo.first()
# Out:
#         pclass  survived      age
# sex
# female       1         1  29.0000
# male         1         1   0.9167

# %%
gbo.get_group('male')
# Out:
#       pclass  survived      age   sex
# 1          1         1   0.9167  male
# 3          1         0  30.0000  male
# 5          1         1  48.0000  male
# 7          1         0  39.0000  male
# 9          1         0  71.0000  male
# ...      ...       ...      ...   ...
# 1302       3         0      NaN  male
# 1303       3         0      NaN  male
# 1306       3         0  26.5000  male
# 1307       3         0  27.0000  male
# 1308       3         0  29.0000  male
#
# [843 rows x 4 columns]

# %%
mbo=df.groupby('age')
# mbo.ngroups
mbo.groups
# Out:
# {0.1667: [763], 0.3333: [747], 0.4167: [1240], 0.6667: [427], 0.75: [657, 658, 1111], 0.8333: [359, 548, 611], 0.9167: [1, 590], 1.0: [339, 478, 492, 762, 826, 895, 937, 1048, 1101, 1187], 2.0: [2, 514, 540, 587, 624, 866, 1096, 1103, 1144, 1156, 1209, 1230], 3.0: [479, 515, 549, 641, 734, 1098, 1112], 4.0: [94, 340, 588, 622, 894, 916, 934, 1142, 1189, 1206], 5.0: [591, 639, 643, 659, 794], 6.0: [273, 430, 623, 678, 1025, 1097], 7.0: [434, 1102, 1143, 1256], 8.0: [377, 385, 398, 541, 1099, 1145], 9.0: [627, 640, 679, 733, 807, 820, 825, 1082, 1208, 1257], 10.0: [828, 1141, 1207, 1265], 11.0: [54, 628, 827, 855], 11.5: [1263], 12.0: [341, 582, 1056], 13.0: [249, 501, 601, 642, 653], 14.0: [55, 513, 569, 830, 1057, 1105, 1236, 1279], 14.5: [1171, 1304], 15.0: [193, 350, 792, 1007, 1047, 1300], 16.0: [159, 187, 195, 416, 510, 602, 604, 709, 761, 787, 810, 818, 829, 1093, 1104, 1161, 1232, 1244, 1275], 17.0: [53, 92, 229, 295, 390, 458, 482, 625, 650, 700, 701, 738, 740, 755, 772, 791, 
# ...

# %%
for name, group in gbo:
    print(name)
    print("----------")
    print(group)
# Out:
# female
# ----------
#       pclass  survived   age     sex
# 0          1         1  29.0  female
# 2          1         0   2.0  female
# 4          1         0  25.0  female
# 6          1         1  63.0  female
# 8          1         1  53.0  female
# ...      ...       ...   ...     ...
# 1286       3         1  38.0  female
# 1290       3         1  47.0  female
# 1300       3         1  15.0  female
# 1304       3         0  14.5  female
# 1305       3         0   NaN  female
#
# [466 rows x 4 columns]
# male
# ----------
#       pclass  survived      age   sex
# 1          1         1   0.9167  male
# 3          1         0  30.0000  male
# 5          1         1  48.0000  male
# 7          1         0  39.0000  male
# 9          1         0  71.0000  male
# ...      ...       ...      ...   ...
# 1302       3         0      NaN  male
# 1303       3         0      NaN  male
# 1306       3         0  26.5000  male
# 1307       3         0  27.0000  male
# ...

# %%
gbo['age'].mean().plot(kind='bar', title="Average by Sex")
# Out:
# <AxesSubplot:title={'center':'Average by Sex'}, xlabel='sex'>

# %%
gbo['age'].min()
# Out:
# sex
# female    0.1667
# male      0.3333
# Name: age, dtype: float64

# %%
gbo['age'].max()
# Out:
# sex
# female    76.0
# male      80.0
# Name: age, dtype: float64

# %%
gbo['sex'].value_counts()
# Out:
# sex     sex
# female  female    466
# male    male      843
# Name: sex, dtype: int64

# %%
titanic.groupby('sex').mean()
# Out:
#           pclass  survived        age     sibsp     parch
# sex
# female  2.154506  0.727468  28.687071  0.652361  0.633047
# male    2.372479  0.190985  30.585233  0.413998  0.247924

# %%
titanic.groupby('pclass')['age'].mean()
# Out:
# pclass
# 1    39.159918
# 2    29.506705
# 3    24.816367
# Name: age, dtype: float64

# %%
car.groupby('Symbol')['High'].max()
# Out:
# Symbol
# GM       65.180000
# LCID     57.750000
# RIVN    179.470001
# Name: High, dtype: float64

# %%
titanic.groupby("sex")['age'].agg(['max','min','mean','median'])
# Out:
#          max     min       mean  median
# sex
# female  76.0  0.1667  28.687071    27.0
# male    80.0  0.3333  30.585233    28.0

# %%
titanic.groupby("sex").agg(['max','min'])
# Out:
#        pclass     survived                                               name  \
#           max min      max min                                            max
# sex
# female      3   1        1   0  del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# male        3   1        1   0                    van Melkebeke, Mr. Philemon
#
#                                            age         sibsp      ... cabin  \
#                                      min   max     min   max min  ...   max
# sex                                                               ...
# female  Abbott, Mrs. Stanton (Rosa Hunt)  76.0  0.1667     8   0  ...    G6
# male                 Abbing, Mr. Anthony  80.0  0.3333     8   0  ...     T
#
#            embarked     boat     body                 home.dest
#        min      max min  max min  max  min                  max min
# sex
# female   ?        S   ?    D   1    ?  206  Zurich, Switzerland   ?
# ...

# %%
titanic.groupby("sex").agg({'age':['max','min'],'pclass':'count'})
# Out:
#          age         pclass
#          max     min  count
# sex
# female  76.0  0.1667    466
# male    80.0  0.3333    843

# %%
def count_nulls(x):
    return x.size - x.count()
titanic.groupby('pclass')['age'].agg(count_nulls)
# Out:
# pclass
# 1     39
# 2     16
# 3    208
# Name: age, dtype: int64

# %%
car.groupby("Symbol").agg({"Open":["min", "max"], "Close":["min", "max"]})
# Out:
#               Open                   Close
#                min         max         min         max
# Symbol
# GM       57.849998   64.330002   59.270000   64.610001
# LCID     42.299999   56.200001   40.750000   55.520000
# RIVN    106.750000  163.800003  100.730003  172.009995

# %%
# Named Aggregate

# %%
car.groupby("Symbol").agg(  min_open=("Open","min"),
                            max_open=("Open","max"),
                            min_close=("Close","min"),
                            max_close=("Close","max"))
# Out:
#           min_open    max_open   min_close   max_close
# Symbol
# GM       57.849998   64.330002   59.270000   64.610001
# LCID     42.299999   56.200001   40.750000   55.520000
# RIVN    106.750000  163.800003  100.730003  172.009995

# %%
s1=titanic.groupby('sex')['age'].mean()
s1.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
s1.index
# Out:
# Index(['female', 'male'], dtype='object', name='sex')

# %%
titanic.groupby(['pclass','sex'])['age'].mean()
# Out:
# pclass  sex
# 1       female    37.037594
#         male      41.029250
# 2       female    27.499191
#         male      30.815401
# 3       female    22.185307
#         male      25.962273
# Name: age, dtype: float64

# %%
df=titanic.groupby(['sex','age']).mean()
df
# Out:
#                   pclass  survived     sibsp     parch
# sex    age
# female 0.1667   3.000000  1.000000  1.000000  2.000000
#        0.7500   3.000000  1.000000  2.000000  1.000000
#        0.9167   2.000000  1.000000  1.000000  2.000000
#        1.0000   2.800000  0.800000  0.800000  1.400000
#        2.0000   2.571429  0.285714  1.428571  1.428571
# ...                  ...       ...       ...       ...
# male   70.0000  1.500000  0.000000  0.500000  0.500000
#        70.5000  3.000000  0.000000  0.000000  0.000000
#        71.0000  1.000000  0.000000  0.000000  0.000000
#        74.0000  3.000000  0.000000  0.000000  0.000000
#        80.0000  1.000000  1.000000  0.000000  0.000000
#
# [166 rows x 4 columns]

# %%
df.index
# Out:
# MultiIndex([('female', 0.1667),
#             ('female',   0.75),
#             ('female', 0.9167),
#             ('female',    1.0),
#             ('female',    2.0),
#             ('female',    3.0),
#             ('female',    4.0),
#             ('female',    5.0),
#             ('female',    6.0),
#             ('female',    7.0),
#             ...
#             (  'male',   63.0),
#             (  'male',   64.0),
#             (  'male',   65.0),
#             (  'male',   66.0),
#             (  'male',   67.0),
#             (  'male',   70.0),
#             (  'male',   70.5),
#             (  'male',   71.0),
#             (  'male',   74.0),
#             (  'male',   80.0)],
#            names=['sex', 'age'], length=166)

# %%
pop=pd.read_csv('data/state_pops.csv')
pop
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pop.set_index('state').index.unique()
# Out:
# Index(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI',
#        'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN',
#        'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH',
#        'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA',
#        'WV', 'WI', 'WY', 'PR', 'USA'],
#       dtype='object', name='state')

# %%
pop.set_index('state').loc['AL']
# Out:
#        year  population
# state
# AL     2012   4817528.0
# AL     2010   4785570.0
# AL     2011   4801627.0
# AL     2009   4757938.0
# AL     2013   4833722.0
# AL     2007   4672840.0
# AL     2008   4718206.0
# AL     2005   4569805.0
# AL     2006   4628981.0
# AL     2004   4530729.0
# AL     2003   4503491.0
# AL     2001   4467634.0
# AL     2002   4480089.0
# AL     1999   4430141.0
# AL     2000   4452173.0
# AL     1998   4404701.0
# AL     1997   4367935.0
# AL     1996   4331103.0
# AL     1995   4296800.0
# AL     1994   4260229.0
# AL     1993   4214202.0
# AL     1992   4154014.0
# AL     1991   4099156.0
# AL     1990   4050055.0

# %%
pop.set_index('year').index.unique()
# Out:
# Int64Index([2012, 2010, 2011, 2009, 2013, 2007, 2008, 2005, 2006, 2004, 2003,
#             2001, 2002, 1999, 2000, 1998, 1997, 1996, 1995, 1994, 1993, 1992,
#             1991, 1990],
#            dtype='int64', name='year')

# %%
pop
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pop.sort_index()
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pop.sort_index(ascending=[False,True], level=[0,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\4192958142.py in <module>
# ----> 1 pop.sort_index(ascending=[False,True], level=[0,1])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    6454         d  4
#    6455         """
# -> 6456         return super().sort_index(
#    6457             axis,
#    6458             level,
#
# ...

# %%
pop.sort_index(inplace=True)

# %%
pop
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pop.loc['CA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\467162336.py in <module>
# ----> 1 pop.loc['CA']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1203         # fall thru to straight lookup
#    1204         self._validate_key(key, axis)
# -> 1205         return self._get_label(key, axis=axis)
#    1206
#    1207     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
# ...

# %%
pop.loc[("CA",2013)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2013
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pop.loc[:,2012,:]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\1806204656.py in <module>
# ----> 1 pop.loc[:,2012,:]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1141
#    1142         # no multi-index, so validate all of the indexers
# -> 1143         tup = self._validate_tuple_indexer(tup)
#    1144
#    1145         # ugly hack for GH #836
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_tuple_indexer(self, key)
# ...

# %%
titanic.loc[19,'name']
# Out:
# 'Beattie, Mr. Thomson'

# %%
pop.loc[("AK",1990):("CA",2012)]
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\542341862.py in <module>
# ----> 1 pop.loc[("AK",1990):("CA",2012)]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1181         if isinstance(key, slice):
#    1182             self._validate_key(key, axis)
# -> 1183             return self._get_slice_axis(key, axis=axis)
#    1184         elif com.is_bool_indexer(key):
#    1185             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
pop.loc[:, [1990,1991,1992],:]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\3404647460.py in <module>
# ----> 1 pop.loc[:, [1990,1991,1992],:]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1141
#    1142         # no multi-index, so validate all of the indexers
# -> 1143         tup = self._validate_tuple_indexer(tup)
#    1144
#    1145         # ugly hack for GH #836
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_tuple_indexer(self, key)
# ...

# %%
pop.loc[slice(None), [1990,1991,1992],:]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\734976421.py in <module>
# ----> 1 pop.loc[slice(None), [1990,1991,1992],:]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1141
#    1142         # no multi-index, so validate all of the indexers
# -> 1143         tup = self._validate_tuple_indexer(tup)
#    1144
#    1145         # ugly hack for GH #836
#
# ...

# %%
pop.index.levels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\2372550641.py in <module>
# ----> 1 pop.index.levels
#
# AttributeError: 'RangeIndex' object has no attribute 'levels'

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
pop.index.get_level_values(0)
# Out:
# RangeIndex(start=0, stop=1272, step=1)

# %%
even_years=pop.index.get_level_values(1)%2==0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\3920392079.py in <module>
# ----> 1 even_years=pop.index.get_level_values(1)%2==0
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_level_values(self, level)
#    2014         Index(['a', 'b', 'c'], dtype='object')
#    2015         """
# -> 2016         self._validate_index_level(level)
#    2017         return self
#    2018
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1933                 )
#    1934             elif level > 0:
# -> 1935                 raise IndexError(
#    1936                     f"Too many levels: Index has only 1 level, not {level + 1}"
#    1937                 )
#
# IndexError: Too many levels: Index has only 1 level, not 2

# %%
even_years
# Out:
# array([ True, False,  True, ..., False,  True, False])

# %%
pop[even_years]
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 2       AL  2011    4801627.0
# 4       AL  2013    4833722.0
# 6       AL  2008    4718206.0
# 8       AL  2006    4628981.0
# ...    ...   ...          ...
# 1262   USA  2004  292805298.0
# 1264   USA  2006  298379912.0
# 1266   USA  2008  304093966.0
# 1268   USA  2009  306771529.0
# 1270   USA  2011  311582564.0
#
# [636 rows x 3 columns]

# %%
pop.index.get_level_values(0)
# Out:
# RangeIndex(start=0, stop=1272, step=1)

# %%
pop.index.get_level_values(0).str[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\1721902586.py in <module>
# ----> 1 pop.index.get_level_values(0).str[1]
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
# ...

# %%
type(pop.index.get_level_values(0).str[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\2993155879.py in <module>
# ----> 1 type(pop.index.get_level_values(0).str[1])
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
# ...

# %%
ends_with_a=pop[pop.index.get_level_values(0).str[1]=='A']
ends_with_a.loc[("CA",1990):("CA",1999)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6500\1706476986.py in <module>
# ----> 1 ends_with_a=pop[pop.index.get_level_values(0).str[1]=='A']
#       2 ends_with_a.loc[("CA",1990):("CA",1999)]
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
# ...

# %%
df=titanic.groupby(['pclass','sex']).mean()

# %%
df
# Out:
#                survived        age     sibsp     parch
# pclass sex
# 1      female  0.965278  37.037594  0.555556  0.472222
#        male    0.340782  41.029250  0.340782  0.279330
# 2      female  0.886792  27.499191  0.500000  0.650943
#        male    0.146199  30.815401  0.327485  0.192982
# 3      female  0.490741  22.185307  0.791667  0.731481
#        male    0.152130  25.962273  0.470588  0.255578

# %%
df.loc[(2)]
# Out:
#         survived        age     sibsp     parch
# sex
# female  0.886792  27.499191  0.500000  0.650943
# male    0.146199  30.815401  0.327485  0.192982

# %%
df.loc[(3,"female")]
# Out:
# survived     0.490741
# age         22.185307
# sibsp        0.791667
# parch        0.731481
# Name: (3, female), dtype: float64

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.groupby(["sex"]).agg({'age':['mean','max']})
# Out:
#               age
#              mean   max
# sex
# female  28.687071  76.0
# male    30.585233  80.0

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
titanic['fare'].value_counts(dropna=False)
# Out:
# 8.05       60
# 13         59
# 7.75       55
# 26         50
# 7.8958     49
#            ..
# 15.05       1
# 14          1
# 15.5792     1
# 12          1
# 7.875       1
# Name: fare, Length: 282, dtype: int64

# %%
titanic['fare'].unique()
# Out:
# array(['211.3375', '151.55', '26.55', '77.9583', '0', '51.4792',
#        '49.5042', '227.525', '69.3', '78.85', '30', '25.925', '247.5208',
#        '76.2917', '75.2417', '52.5542', '221.7792', '26', '91.0792',
#        '135.6333', '35.5', '31', '164.8667', '262.375', '55', '30.5',
#        '50.4958', '39.6', '27.7208', '134.5', '26.2875', '27.4458',
#        '512.3292', '5', '47.1', '120', '61.175', '53.1', '86.5', '29.7',
#        '136.7792', '52', '25.5875', '83.1583', '25.7', '71', '71.2833',
#        '57', '81.8583', '106.425', '56.9292', '78.2667', '31.6792',
#        '31.6833', '110.8833', '26.3875', '27.75', '263', '133.65', '49.5',
#        '79.2', '38.5', '211.5', '59.4', '89.1042', '34.6542', '28.5',
#        '153.4625', '63.3583', '55.4417', '76.7292', '42.4', '83.475',
#        '93.5', '42.5', '51.8625', '50', '57.9792', '90', '30.6958', '80',
#        '28.7125', '25.9292', '39.4', '45.5', '146.5208', '82.1708',
# ...

# %%
titanic['fare'].replace(["?"],[None],inplace=True)

# %%
titanic['fare']=pd.to_numeric(titanic['fare'])

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 143.3+ KB

# %%
dfi=titanic.groupby(["sex"]).agg({
    'age':['mean','max'],
    'fare':['mean','max','min']})

# %%
dfi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, female to male
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   (age, mean)   2 non-null      float64
#  1   (age, max)    2 non-null      float64
#  2   (fare, mean)  2 non-null      float64
#  3   (fare, max)   2 non-null      float64
#  4   (fare, min)   2 non-null      float64
# dtypes: float64(5)
# memory usage: 96.0+ bytes

# %%
dfi.index
# Out:
# Index(['female', 'male'], dtype='object', name='sex')

# %%
dfi.columns
# Out:
# MultiIndex([( 'age', 'mean'),
#             ( 'age',  'max'),
#             ('fare', 'mean'),
#             ('fare',  'max'),
#             ('fare',  'min')],
#            )

# %%
dfi['age']['mean']
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: mean, dtype: float64

# %%
pop=pop.set_index(["state",'year'])

# %%
pop.unstack()
# Out:
#         population                                                      \
# year          1990         1991         1992         1993         1994
# state
# AK        553290.0     570193.0     588736.0     599434.0     603308.0
# AL       4050055.0    4099156.0    4154014.0    4214202.0    4260229.0
# AR       2356586.0    2383144.0    2415984.0    2456303.0    2494019.0
# AZ       3684097.0    3788576.0    3915740.0    4065440.0    4245089.0
# CA      29959515.0   30470736.0   30974659.0   31274928.0   31484435.0
# CO       3307618.0    3387119.0    3495939.0    3613734.0    3724168.0
# CT       3291967.0    3302895.0    3300712.0    3309175.0    3316121.0
# DC        605321.0     600870.0     597567.0     595302.0     589240.0
# DE        669567.0     683080.0     694927.0     706378.0     717545.0
# FL      13033307.0   13369798.0   13650553.0   13927185.0   14239444.0
# GA       6512602.0    6653005.0    6817203.0    6978240.0    7157165.0
# ...

# %%
unstacked_df=pop.unstack(level='state')

# %%
unstacked_df.stack().unstack()
# Out:
#       population                                                          \
# state         AK         AL         AR         AZ          CA         CO
# year
# 1990    553290.0  4050055.0  2356586.0  3684097.0  29959515.0  3307618.0
# 1991    570193.0  4099156.0  2383144.0  3788576.0  30470736.0  3387119.0
# 1992    588736.0  4154014.0  2415984.0  3915740.0  30974659.0  3495939.0
# 1993    599434.0  4214202.0  2456303.0  4065440.0  31274928.0  3613734.0
# 1994    603308.0  4260229.0  2494019.0  4245089.0  31484435.0  3724168.0
# 1995    604412.0  4296800.0  2535399.0  4432499.0  31696582.0  3826653.0
# 1996    608569.0  4331103.0  2572109.0  4586940.0  32018834.0  3919972.0
# 1997    612968.0  4367935.0  2601091.0  4736990.0  32486010.0  4018293.0
# 1998    619933.0  4404701.0  2626289.0  4883342.0  32987675.0  4116639.0
# 1999    624779.0  4430141.0  2651860.0  5023823.0  33499204.0  4226018.0
# 2000    627963.0  4452173.0  2678588.0  5160586.0  33987977.0  4326921.0
# ...

# %%
pop.unstack()
# Out:
#         population                                                      \
# year          1990         1991         1992         1993         1994
# state
# AK        553290.0     570193.0     588736.0     599434.0     603308.0
# AL       4050055.0    4099156.0    4154014.0    4214202.0    4260229.0
# AR       2356586.0    2383144.0    2415984.0    2456303.0    2494019.0
# AZ       3684097.0    3788576.0    3915740.0    4065440.0    4245089.0
# CA      29959515.0   30470736.0   30974659.0   31274928.0   31484435.0
# CO       3307618.0    3387119.0    3495939.0    3613734.0    3724168.0
# CT       3291967.0    3302895.0    3300712.0    3309175.0    3316121.0
# DC        605321.0     600870.0     597567.0     595302.0     589240.0
# DE        669567.0     683080.0     694927.0     706378.0     717545.0
# FL      13033307.0   13369798.0   13650553.0   13927185.0   14239444.0
# GA       6512602.0    6653005.0    6817203.0    6978240.0    7157165.0
# ...

# %%
titanic.groupby(['pclass','sex'])['age'].mean()
# Out:
# pclass  sex
# 1       female    37.037594
#         male      41.029250
# 2       female    27.499191
#         male      30.815401
# 3       female    22.185307
#         male      25.962273
# Name: age, dtype: float64

# %%
titanic.groupby(['pclass','sex'])['age'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass,sex'>

# %%
titanic.groupby(['pclass','sex'])['age'].mean().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
pop.groupby(level=1).sum()
# Out:
#        population
# year
# 1990  499245628.0
# 1991  505961884.0
# 1992  513028462.0
# 1993  519837190.0
# 1994  526251652.0
# 1995  532556806.0
# 1996  538788582.0
# 1997  545293864.0
# 1998  551708232.0
# 1999  558080362.0
# 2000  568135427.0
# 2001  573756684.0
# 2002  579074087.0
# 2003  584041961.0
# 2004  589437474.0
# 2005  594854560.0
# 2006  600565038.0
# 2007  606245409.0
# 2008  611948798.0
# 2009  617283468.0
# 2010  622373798.0
# 2011  626851708.0
# 2012  631398915.0
# 2013  635872764.0

# %%
titanic.sort_values('name').tail(20)
# Out:
#       pclass  survived                                     name     sex   age  \
# 319        1         1                Wilson, Miss. Helen Alice  female  31.0
# 1295       3         0                      Windelov, Mr. Einar    male  21.0
# 1296       3         0                         Wirz, Mr. Albert    male  27.0
# 1297       3         0                   Wiseman, Mr. Phillippe    male   NaN
# 1298       3         0                Wittevrongel, Mr. Camille    male  36.0
# 320        1         1                        Woolner, Mr. Hugh    male   NaN
# 598        2         1                     Wright, Miss. Marion  female  26.0
# 321        1         0                       Wright, Mr. George    male  62.0
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 322        1         1                 Young, Miss. Marie Grice  female  36.0
# ...

# %%
titanic.groupby('survived').mean()
# Out:
#             pclass        age     sibsp     parch       fare
# survived
# 0         2.500618  30.545369  0.521632  0.328801  23.353831
# 1         1.962000  28.918228  0.462000  0.476000  49.361184

# %%
titanic.groupby('survived')
