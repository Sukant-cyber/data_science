# %%
import pandas as pd
titanic=pd.read_csv('titanic.csv')
houses=pd.read_csv('kc_house_data.csv')
btc=pd.read_csv('BTC-USD.csv')

# %%
df=titanic.head()

# %%
df.Sex == 'male'
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Sex, dtype: bool

# %%
df[df.Sex == 'male']
# Out:
#    PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 0          892         0       3           Kelly, Mr. James  male  34.5
# 2          894         0       2  Myles, Mr. Thomas Francis  male  62.0
# 3          895         0       3           Wirz, Mr. Albert  male  27.0
#
#    SibSp  Parch  Ticket    Fare Cabin Embarked
# 0      0      0  330911  7.8292   NaN        Q
# 2      0      0  240276  9.6875   NaN        Q
# 3      0      0  315154  8.6625   NaN        S

# %%
bools=[True,True,False,True,False]
df[bools]
# Aisa hi kuch hota hai jo false hai usko reject kr diya jata hai aur true wala print hota hai
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 3          895         0       3                  Wirz, Mr. Albert    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 3  27.0      0      0  315154  8.6625   NaN        S

# %%
titanic[titanic.Survived == 0]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
titanic[titanic.Survived == 0].Survived.value_counts()
# Out:
# 0    266
# Name: Survived, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
houses[houses.bedrooms<=0]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 875    6306400140  20140612T000000  1095000.0         0       0.00
# 3119   3918400017  20150205T000000   380000.0         0       0.00
# 3467   1453602309  20140805T000000   288000.0         0       1.50
# 4868   6896300380  20141002T000000   228000.0         0       1.00
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 8477   2569500210  20141117T000000   339950.0         0       2.50
# 8484   2310060040  20140925T000000   240000.0         0       2.50
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 12653  7849202299  20150218T000000   320000.0         0       2.50
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 18379  1222029077  20141029T000000   265000.0         0       0.75
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses[houses["bedrooms"].between(5,7)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 14     1175000570  20150312T000000   530000.0         5       2.00
# 22     7137970340  20140703T000000   285000.0         5       2.50
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 51     7231300125  20150217T000000   345000.0         5       2.50
# 54     4217401195  20150303T000000   920000.0         5       2.25
# ...           ...              ...        ...       ...        ...
# 21564  7168100015  20141009T000000   579950.0         5       2.75
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21596  7502800100  20140813T000000   679950.0         5       2.75
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14            1810      4850     1.5           0     0  ...      7
# ...

# %%
houses[houses["bedrooms"].between(5,7)].bedrooms.value_counts()
# Out:
# 5    1601
# 6     272
# 7      38
# Name: bedrooms, dtype: int64

# %%
whr=pd.read_csv('world-happiness-report-2021.csv')

# %%
whr
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
netflix=pd.read_csv('netflix_titles.csv')

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
count=["India","United States"]
netflix[netflix.country.isin(count)]
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 4         s5  TV Show          Kota Factory              NaN
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 24       s25    Movie                 Jeans       S. Shankar
# ...      ...      ...                   ...              ...
# 8799   s8800    Movie                 Zenda   Avadhoot Gupte
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...

# %%
netflix[netflix.country.isin(count)].country.value_counts()
# Out:
# United States    2818
# India             972
# Name: country, dtype: int64

# %%
clas = titanic.Pclass==3
died = titanic.Survived==0
titanic[clas&died].Sex.value_counts()
# Out:
# male    146
# Name: Sex, dtype: int64

# %%
houses[(houses["waterfront"]==1) & (houses["price"]<=500000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 264    2123039032  20141027T000000  369900.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 1949   1922039062  20150420T000000  480000.0         2       1.50
# 3829   8550001515  20141001T000000  429592.0         2       2.75
# 6102    222029026  20140917T000000  340000.0         2       0.75
# 8277    221029019  20150428T000000  400000.0         3       2.50
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 11556  2013802030  20140911T000000  357000.0         3       2.00
# 13525  2013802060  20140927T000000  500000.0         2       1.00
# 14827  2423029009  20140617T000000  465000.0         2       2.00
# 16570  2923039243  20141113T000000  340000.0         4       1.00
# 18275  2781600195  20141117T000000  285000.0         1       1.00
# 18848  7631800110  20140918T000000  380000.0         3       2.50
# ...

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
high_quality=houses["grade"]>=11
good_view=houses["view"]>=4
houses[high_quality & good_view]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 540     622049114  20150218T000000  2125000.0         3       2.50
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# 2444   7524900003  20141210T000000  3278000.0         2       1.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2713   7851980260  20140730T000000  1110000.0         5       3.50
# 3157   1827200265  20140911T000000  1899000.0         2       2.75
# 3586   9272200090  20150204T000000  1598890.0         4       4.50
# 4013    724069059  20140509T000000  2400000.0         3       2.25
# 4190   2303900090  20140729T000000  2880500.0         4       2.50
# 4406   3505100756  20141106T000000  2050000.0         4       3.00
# ...

# %%
new_houses=houses[(houses['yr_built']>=2014) | (houses['yr_renovated']>=2014)]

# %%
new_houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000  861990.0         5       2.75
# 63     9528102996  20141207T000000  549000.0         3       1.75
# 133    8929000270  20140512T000000  453246.0         3       2.50
# 139    2767603505  20140507T000000  519950.0         3       2.25
# 211    1025049114  20140717T000000  625504.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21598  8956200760  20141013T000000  541800.0         4       2.50
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21604  9834201367  20150126T000000  429000.0         3       2.00
# 21605  3448900210  20141014T000000  610685.0         4       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
new_houses.sort_values("yr_built")
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 2566   3037200060  20140926T000000   499000.0         3       2.50
# 11695  5699000070  20140528T000000  1400000.0         4       3.25
# 15046  9187200275  20150420T000000   905000.0         4       2.25
# 379    7132300695  20150421T000000   435000.0         3       1.50
# 2505   1005000036  20140613T000000   285000.0         3       1.75
# ...           ...              ...        ...       ...        ...
# 4154   8077100031  20150422T000000   631000.0         3       2.25
# 20369  4385700250  20150407T000000  1800000.0         4       3.50
# 21270  1773100541  20150417T000000   389950.0         3       2.25
# 21501  4233600150  20150203T000000  1150000.0         5       4.25
# 20798   952005863  20150505T000000   643950.0         3       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2566          1750      2150     2.5           0     0  ...      7
# ...

# %%
netflix[(netflix["director"]=="Christopher Nolan") | ((netflix['country']=="India")&(netflix['type']=='Movie'))]
# Out:
#      show_id   type                  title                 director  \
# 24       s25  Movie                  Jeans               S. Shankar
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam             Rahul Rawail
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor
# 118     s119  Movie                Gurgaon            Shanker Raman
# ...      ...    ...                    ...                      ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %%
netflix[netflix['director'].isin(['Christopher Nolan','Karan Johar','Rohit Shetty'])]
# Out:
#      show_id   type                     title           director  \
# 301     s302  Movie           Chennai Express       Rohit Shetty
# 340     s341  Movie                 Inception  Christopher Nolan
# 1679   s1680  Movie                   Singham       Rohit Shetty
# 1940   s1941  Movie           Golmaal Returns       Rohit Shetty
# 2730   s2731  Movie    Kabhi Alvida Naa Kehna        Karan Johar
# 2731   s2732  Movie  Kabhi Khushi Kabhie Gham        Karan Johar
# 2734   s2735  Movie        Kuch Kuch Hota Hai        Karan Johar
# 5616   s5617  Movie                   Dilwale       Rohit Shetty
# 6870   s6871  Movie    Golmaal: Fun Unlimited       Rohit Shetty
#
#                                                    cast  \
# 301   Shah Rukh Khan, Deepika Padukone, Nikitin Dhee...
# 340   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1679  Ajay Devgn, Kajal Aggarwal, Prakash Raj, Sonal...
# 1940  Ajay Devgn, Kareena Kapoor, Arshad Warsi, Tuss...
# ...

# %%
netflix[netflix['director'].isin(['Christopher Nolan','Karan Johar','Rohit Shetty'])].director.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
netflix[(netflix['director'].isin(['Christopher Nolan','Karan Johar','Rohit Shetty'])) | (netflix['release_year']>2020)]
# Out:
#      show_id     type                   title         director  \
# 1         s2  TV Show           Blood & Water              NaN
# 2         s3  TV Show               Ganglands  Julien Leclercq
# 3         s4  TV Show   Jailbirds New Orleans              NaN
# 4         s5  TV Show            Kota Factory              NaN
# 5         s6  TV Show           Midnight Mass    Mike Flanagan
# ...      ...      ...                     ...              ...
# 2734   s2735    Movie      Kuch Kuch Hota Hai      Karan Johar
# 2920   s2921  TV Show           Love Is Blind              NaN
# 5616   s5617    Movie                 Dilwale     Rohit Shetty
# 6870   s6871    Movie  Golmaal: Fun Unlimited     Rohit Shetty
# 8437   s8438  TV Show  The Netflix Afterparty              NaN
#
#                                                    cast        country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.release_year.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='release_year'>

# %%
newly_built=houses.yr_built>=2014
newly_renovated=houses.yr_renovated>=2014
# recent_houses=newly_built | newly_renovated

# %%
new=houses[newly_built | newly_renovated].id.count()
old=houses[~(newly_built | newly_renovated)].id.count()
old
# Out:
# 20909

# %%
netflix[~(netflix.director.isna())]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
netflix[netflix.director.notna()]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
titanic=pd.read_csv('full.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic[(titanic['Sex']=='female')].Survived.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
titanic[(titanic['Sex']=='male')].Survived.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
titanic.Survived.value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
bestsellers=pd.read_csv('amazon_products.csv')

# %%
bestsellers
# Out:
#                                             Book Name           Author  \
# 0                                Finding Me: A Memoir      Viola Davis
# 1   Atomic Habits: An Easy & Proven Way to Build G...      James Clear
# 2   This Will Not Pass: Trump, Biden, and the Batt...  Jonathan Martin
# 3                                       Bill O'Reilly              NaN
# 4                                Just Tyrus: A Memoir            Tyrus
# ..                                                ...              ...
# 57  Why a Daughter Needs a Mom: Celebrate Your Mot...  Gregory E. Lang
# 58                            Berserk Deluxe Volume 1    Kentaro Miura
# 59                                     Magnolia Table    Joanna Gaines
# 60                       The Lincoln Highway: A Novel      Amor Towles
# 61                                                NaN              NaN
#
#      Price Customers_Rated                     Rating Book_cover
# ...
