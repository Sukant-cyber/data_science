# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv('data/titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic['age']=titanic['age'].replace(["?"],[None],inplace=True)
# titanic['fare']=titanic['fare'].replace(["?"],[None],inplace=True).astype('float')
titanic['age']=pd.to_numeric(titanic['age'])

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        0 non-null      float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        0 non-null      float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
df=titanic['name'].str.upper()
df
# Out:
# 0                         ALLEN, MISS. ELISABETH WALTON
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
titanic.name
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic['lower_case_name']=titanic.name.str.lower()

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# ...

# %%
titanic['first_cabin']=titanic.cabin.str[0]

# %%
titanic['first_cabin'].value_counts()
# Out:
# ?    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: first_cabin, dtype: int64

# %%
titanic.groupby('first_cabin').mean()
# Out:
#                pclass  survived  age     sibsp     parch
# first_cabin
# ?            2.617357  0.302761  NaN  0.503945  0.367850
# A            1.000000  0.500000  NaN  0.181818  0.181818
# B            1.000000  0.723077  NaN  0.446154  0.661538
# C            1.000000  0.606383  NaN  0.680851  0.414894
# D            1.130435  0.695652  NaN  0.413043  0.260870
# E            1.243902  0.731707  NaN  0.341463  0.390244
# F            2.380952  0.619048  NaN  0.428571  0.523810
# G            3.000000  0.600000  NaN  0.600000  1.200000
# T            1.000000  0.000000  NaN  0.000000  0.000000

# %%
titanic.groupby('first_cabin')['survived'].mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='first_cabin'>

# %%
coun=titanic['cabin'].count()
titanic['new']="B5"
i=0
while(i<1309):
    titanic['new'][i]=titanic['cabin'][i].split(" ")
    i=i+1
# Out:
# C:\Users\Sukant\AppData\Local\Temp\ipykernel_1352\3694662687.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['new'][i]=titanic['cabin'][i].split(" ")

# %%
titanic.new[0]
# Out:
# ['B5']

# %%
i=0
while i<1309:
    titanic['new'][i]=titanic['new'][i][0]
    i=i+1
# Out:
# C:\Users\Sukant\AppData\Local\Temp\ipykernel_1352\855224044.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['new'][i]=titanic['new'][i][0]

# %%
titanic.groupby('new')['survived'].mean().tail(20).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='new'>

# %%
s = pd.Series(['1. Hawk.  ', '2. Pickle!\n', '3. Melonhead?\t'])
s
# Out:
# 0         1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.strip(to_strip="123.!?\n\t ")
# Out:
# 0         Hawk
# 1       Pickle
# 2    Melonhead
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex  age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# ...

# %%
tit=pd.read_csv('full.csv')
tit.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
titanic['name'].str.split(" ",expand=True,n=3)
# Out:
#                0        1            2                           3
# 0         Allen,    Miss.    Elisabeth                      Walton
# 1       Allison,  Master.       Hudson                      Trevor
# 2       Allison,    Miss.        Helen                     Loraine
# 3       Allison,      Mr.       Hudson            Joshua Creighton
# 4       Allison,     Mrs.       Hudson  J C (Bessie Waldo Daniels)
# ...          ...      ...          ...                         ...
# 1304     Zabour,    Miss.       Hileni                        None
# 1305     Zabour,    Miss.      Thamine                        None
# 1306   Zakarian,      Mr.  Mapriededer                        None
# 1307   Zakarian,      Mr.        Ortin                        None
# 1308  Zimmerman,      Mr.          Leo                        None
#
# [1309 rows x 4 columns]

# %%
ufo=pd.read_csv('data/nuforc_reports.csv')

# %%
ufo.duration.str.replace("seconds|minutes",'', regex=True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
def abb(r):
    return r.group()[0]
ufo['duration'].str.replace("seconds|minutes|hours",abb,regex=True)
# Out:
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %%
ufo['duration'].str.contains('hour')
# Out:
# 0        False
# 1        False
# 2          NaN
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
ufo[ufo['duration'].str.contains('year',na=False)]
# Out:
#                                                  summary  \
# 5388   For many years since 1978 to 2004 there have b...
# 6639            this all happened in one little section.
# 8542   Orange or amber balls or orbs of light multipl...
# 11420                                     strange lights
# 16450  Back in early 90's at area 51, when the media ...
# 16666  First time it was a bright light and missing t...
# 19617  Not a siting but a posible visit? I started ou...
# 20718  The 12 UFO we seen brite yellow like a street ...
# 43321  Alien report.  ((NUFORC Note:  We cannot confi...
# 44828  Sightings of Cube, Triangle, Cigar , Diamond  ...
# 45390                       Sky Watching of Another Kind
# 45786  Strange lights in the sky that move and follow...
# 49246  Firstly, I was stunned and stared at the objec...
# 50311             Multiple sightings over the past year.
# 65311  ((HOAX??))  Hovering Craft seen for nearly one...
# ...
